# %%
import requests
url = "https://jobinja.ir/companies/dornica-4"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36"
}
response = requests.get(url, headers=headers)
response.text
# Out:
# '<!DOCTYPE html><html lang="en"><head><meta charset="UTF-8"><meta name="viewport" content="width=device-width"><link href="/cdn-cgi/assets/css/static-pages-2.6.0.css" rel="stylesheet"><link rel="icon" type="image/x-icon" href="//#DOMAIN#/favicon.ico"><title></title></head><body><section class="error-section error-section--waiting error-section--ltr error-section--hide" id="en"><div class="container"><div class="error-section__wrapper error-section__wrapper--waiting"><div class="error-section__information"><h1 class="error-section__title"></h1><h1 class="error-section__subtitle error-section__subtitle--waiting">Checking your browser before accessing the website...</h1><div class="error-section__contents"><p class="error-section__content">Please complete the security check before accessing the website.</p></div><div class="redirect__captcha" id="captcha"></div></div></div></div></section><section class="error-section error-section--waiting error-section--hide" id="fa"><div class="container"><div class="error-section__wrapper error-section__wrapper--waiting"><div class="error-section__information"><h1 class="error-section__title"></h1><h1 class="error-section__subtitle error-section__subtitle--waiting">Ø¯Ø± Ø\xadØ§Ù\x84 Ø¨Ø±Ø±Ø³Û\x8c Ù\x85Ø±Ù\x88Ø±Ú¯Ø±Ø\x8c Ù¾Û\x8cØ´ Ø§Ø² Ø§Ù\x86ØªÙ\x82Ø§Ù\x84 Ø¨Ù\x87 Ø³Ø§Û\x8cØª Ù\x87Ø³ØªÛ\x8cÙ\x85 ...</h1><div class="error-section__contents"><p class="error-section__content">Ø¨Ø±Ø§Û\x8c Ø¯Ø³ØªØ±Ø³Û\x8c Ø¨Ù\x87 Ù\x88Ø¨â\x80\x8cØ³Ø§Û\x8cØª Ù\x85Ù\x88Ø±Ø¯Ù\x86Ø¸Ø±Ø\x8c Ú¯Ø²Û\x8cÙ\x86Ù\x87 Ø²Û\x8cØ± Ø±Ø§ ØªØ§Û\x8cÛ\x8cØ¯ Ú©Ù\x86Û\x8cØ¯.</p></div><div class="redirect__captcha" id="captcha_element"></div></div></div></div></section><script>"use strict";\n\nvar isTehranTimezone = function isTehranTimezone() {\n  try {\n    var intlName = window.Intl.DateTimeFormat().resolvedOptions().timeZone;\n    if (intlName) {\n      return intlName.toLowerCase().includes(\'tehran\');\n    }\n  } catch (e) {}\n\n  var now = new Date();\n  return now.toString().toLowerCase().includes(\'iran\');\n};\n\nvar showPage = function showPage() {\n  var errorPage;\n  var headTitleElement = document.getElementsByTagName(\'title\');\n\n  if (isTehranTimezone()) {\n    errorPage = document.getElementById(\'fa\');\n  } else {\n    errorPage = document.getElementById(\'en\');\n  }\n\n  var lang;\n  if (isTehranTimezone()) {\n    lang = \'fa\';\n  } else {\n    lang = \'en\';\n  }\n\n  var pageTitle = errorPage.getElementsByClassName(\'error-section__title\')[0].textContent;\n  headTitleElement[0].innerHTML = pageTitle;\n  errorPage.classList.remove(\'error-section--hide\');\n  afterShowPage(errorPage, lang)\n};\n\nwindow.addEventListener("load", showPage);</script><script type="text/javascript">window.AR_SiteKey = \'6Le8dMkUAAAAAEzy7WYOlWbYh0eun-xK0j5aXt6W\';\nwindow.AR_Key = \'__arcsrc\';\nwindow.AR_Domain = \'jobinja.ir\';\nwindow.AR_Age = \'900\';\nwindow.AR_SameSite = \'; SameSite=Lax\';</script>\n<script type="text/javascript" src="/cdn-cgi/assets/js/recaptcha.js"></script>\n<script id="arvanRecaptcha" defer="defer" async="async"></script>\n<script type="text/javascript">"use strict";\n\nif (typeof isTehranTimezone === \'undefined\') {\n    var isTehranTimezone = function isTehranTimezone() {\n        try {\n            var intlName = window.Intl.DateTimeFormat().resolvedOptions().timeZone;\n            if (intlName) {\n                return intlName.toLowerCase().includes(\'tehran\');\n            }\n        } catch (e) {}\n\n        var now = new Date();\n        return now.toString().toLowerCase().includes(\'iran\');\n    };\n}\n\nif (typeof showPage === \'undefined\') {\n    var showPage = function showPage() {\n        if (!document.getElementsByClassName(\'redirect__captcha\')[0]) {\n            const placeholder = document.getElementById(\'arvanRecaptcha\');\n            const testDiv = document.createElement(\'div\');\n            testDiv.className = \'redirect__captcha\';\n            placeholder.insertAdjacentEle ...

# %%
[
    {
        "page_number": 1,
        "html_content": response.text,
    },
    {
        "page_number": 2,
        "html_content": response.text
    },
    {
        "page_number": 3,
        "html_content": response.text
    }
]
# Out:
# [{'page_number': 1,
#   'html_content': '<!DOCTYPE html><html lang="en"><head><meta charset="UTF-8"><meta name="viewport" content="width=device-width"><link href="/cdn-cgi/assets/css/static-pages-2.6.0.css" rel="stylesheet"><link rel="icon" type="image/x-icon" href="//#DOMAIN#/favicon.ico"><title></title></head><body><section class="error-section error-section--waiting error-section--ltr error-section--hide" id="en"><div class="container"><div class="error-section__wrapper error-section__wrapper--waiting"><div class="error-section__information"><h1 class="error-section__title"></h1><h1 class="error-section__subtitle error-section__subtitle--waiting">Checking your browser before accessing the website...</h1><div class="error-section__contents"><p class="error-section__content">Please complete the security check before accessing the website.</p></div><div class="redirect__captcha" id="captcha"></div></div></div></div></section><section class="error-section error-section--waiting error-section--hide" id="fa"><div class="container"><div class="error-section__wrapper error-section__wrapper--waiting"><div class="error-section__information"><h1 class="error-section__title"></h1><h1 class="error-section__subtitle error-section__subtitle--waiting">Ø¯Ø± Ø\xadØ§Ù\x84 Ø¨Ø±Ø±Ø³Û\x8c Ù\x85Ø±Ù\x88Ø±Ú¯Ø±Ø\x8c Ù¾Û\x8cØ´ Ø§Ø² Ø§Ù\x86ØªÙ\x82Ø§Ù\x84 Ø¨Ù\x87 Ø³Ø§Û\x8cØª Ù\x87Ø³ØªÛ\x8cÙ\x85 ...</h1><div class="error-section__contents"><p class="error-section__content">Ø¨Ø±Ø§Û\x8c Ø¯Ø³ØªØ±Ø³Û\x8c Ø¨Ù\x87 Ù\x88Ø¨â\x80\x8cØ³Ø§Û\x8cØª Ù\x85Ù\x88Ø±Ø¯Ù\x86Ø¸Ø±Ø\x8c Ú¯Ø²Û\x8cÙ\x86Ù\x87 Ø²Û\x8cØ± Ø±Ø§ ØªØ§Û\x8cÛ\x8cØ¯ Ú©Ù\x86Û\x8cØ¯.</p></div><div class="redirect__captcha" id="captcha_element"></div></div></div></div></section><script>"use strict";\n\nvar isTehranTimezone = function isTehranTimezone() {\n  try {\n    var intlName = window.Intl.DateTimeFormat().resolvedOptions().timeZone;\n    if (intlName) {\n      return intlName.toLowerCase().includes(\'tehran\');\n    }\n  } catch (e) {}\n\n  var now = new Date();\n  return now.toString().toLowerCase().includes(\'iran\');\n};\n\nvar showPage = function showPage() {\n  var errorPage;\n  var headTitleElement = document.getElementsByTagName(\'title\');\n\n  if (isTehranTimezone()) {\n    errorPage = document.getElementById(\'fa\');\n  } else {\n    errorPage = document.getElementById(\'en\');\n  }\n\n  var lang;\n  if (isTehranTimezone()) {\n    lang = \'fa\';\n  } else {\n    lang = \'en\';\n  }\n\n  var pageTitle = errorPage.getElementsByClassName(\'error-section__title\')[0].textContent;\n  headTitleElement[0].innerHTML = pageTitle;\n  errorPage.classList.remove(\'error-section--hide\');\n  afterShowPage(errorPage, lang)\n};\n\nwindow.addEventListener("load", showPage);</script><script type="text/javascript">window.AR_SiteKey = \'6Le8dMkUAAAAAEzy7WYOlWbYh0eun-xK0j5aXt6W\';\nwindow.AR_Key = \'__arcsrc\';\nwindow.AR_Domain = \'jobinja.ir\';\nwindow.AR_Age = \'900\';\nwindow.AR_SameSite = \'; SameSite=Lax\';</script>\n<script type="text/javascript" src="/cdn-cgi/assets/js/recaptcha.js"></script>\n<script id="arvanRecaptcha" defer="defer" async="async"></script>\n<script type="text/javascript">"use strict";\n\nif (typeof isTehranTimezone === \'undefined\') {\n    var isTehranTimezone = function isTehranTimezone() {\n        try {\n            var intlName = window.Intl.DateTimeFormat().resolvedOptions().timeZone;\n            if (intlName) {\n                return intlName.toLowerCase().includes(\'tehran\');\n            }\n        } catch (e) {}\n\n        var now = new Date();\n        return now.toString().toLowerCase().includes(\'iran\');\n    };\n}\n\nif (typeof showPage === \'undefined\') {\n    var showPage = function showPage() {\n        if (!document.getElementsByClassName(\'redirect__captcha\')[0]) {\n            const placeholder = document.getElementById(\'arvanRecaptcha\');\n            const testDiv = document.createElement(\'div\');\n            testDiv.className = \'redirect__captcha\';\n            placeholder ...
#  {'page_number': 2,
#   'html_content': '<!DOCTYPE html><html lang="en"><head><meta charset="UTF-8"><meta name="viewport" content="width=device-width"><link href="/cdn-cgi/assets/css/static-pages-2.6.0.css" rel="stylesheet"><link rel="icon" type="image/x-icon" href="//#DOMAIN#/favicon.ico"><title></title></head><body><section class="error-section error-section--waiting error-section--ltr error-section--hide" id="en"><div class="container"><div class="error-section__wrapper error-section__wrapper--waiting"><div class="error-section__information"><h1 class="error-section__title"></h1><h1 class="error-section__subtitle error-section__subtitle--waiting">Checking your browser before accessing the website...</h1><div class="error-section__contents"><p class="error-section__content">Please complete the security check before accessing the website.</p></div><div class="redirect__captcha" id="captcha"></div></div></div></div></section><section class="error-section error-section--waiting error-section--hide" id="fa"><div class="container"><div class="error-section__wrapper error-section__wrapper--waiting"><div class="error-section__information"><h1 class="error-section__title"></h1><h1 class="error-section__subtitle error-section__subtitle--waiting">Ø¯Ø± Ø\xadØ§Ù\x84 Ø¨Ø±Ø±Ø³Û\x8c Ù\x85Ø±Ù\x88Ø±Ú¯Ø±Ø\x8c Ù¾Û\x8cØ´ Ø§Ø² Ø§Ù\x86ØªÙ\x82Ø§Ù\x84 Ø¨Ù\x87 Ø³Ø§Û\x8cØª Ù\x87Ø³ØªÛ\x8cÙ\x85 ...</h1><div class="error-section__contents"><p class="error-section__content">Ø¨Ø±Ø§Û\x8c Ø¯Ø³ØªØ±Ø³Û\x8c Ø¨Ù\x87 Ù\x88Ø¨â\x80\x8cØ³Ø§Û\x8cØª Ù\x85Ù\x88Ø±Ø¯Ù\x86Ø¸Ø±Ø\x8c Ú¯Ø²Û\x8cÙ\x86Ù\x87 Ø²Û\x8cØ± Ø±Ø§ ØªØ§Û\x8cÛ\x8cØ¯ Ú©Ù\x86Û\x8cØ¯.</p></div><div class="redirect__captcha" id="captcha_element"></div></div></div></div></section><script>"use strict";\n\nvar isTehranTimezone = function isTehranTimezone() {\n  try {\n    var intlName = window.Intl.DateTimeFormat().resolvedOptions().timeZone;\n    if (intlName) {\n      return intlName.toLowerCase().includes(\'tehran\');\n    }\n  } catch (e) {}\n\n  var now = new Date();\n  return now.toString().toLowerCase().includes(\'iran\');\n};\n\nvar showPage = function showPage() {\n  var errorPage;\n  var headTitleElement = document.getElementsByTagName(\'title\');\n\n  if (isTehranTimezone()) {\n    errorPage = document.getElementById(\'fa\');\n  } else {\n    errorPage = document.getElementById(\'en\');\n  }\n\n  var lang;\n  if (isTehranTimezone()) {\n    lang = \'fa\';\n  } else {\n    lang = \'en\';\n  }\n\n  var pageTitle = errorPage.getElementsByClassName(\'error-section__title\')[0].textContent;\n  headTitleElement[0].innerHTML = pageTitle;\n  errorPage.classList.remove(\'error-section--hide\');\n  afterShowPage(errorPage, lang)\n};\n\nwindow.addEventListener("load", showPage);</script><script type="text/javascript">window.AR_SiteKey = \'6Le8dMkUAAAAAEzy7WYOlWbYh0eun-xK0j5aXt6W\';\nwindow.AR_Key = \'__arcsrc\';\nwindow.AR_Domain = \'jobinja.ir\';\nwindow.AR_Age = \'900\';\nwindow.AR_SameSite = \'; SameSite=Lax\';</script>\n<script type="text/javascript" src="/cdn-cgi/assets/js/recaptcha.js"></script>\n<script id="arvanRecaptcha" defer="defer" async="async"></script>\n<script type="text/javascript">"use strict";\n\nif (typeof isTehranTimezone === \'undefined\') {\n    var isTehranTimezone = function isTehranTimezone() {\n        try {\n            var intlName = window.Intl.DateTimeFormat().resolvedOptions().timeZone;\n            if (intlName) {\n                return intlName.toLowerCase().includes(\'tehran\');\n            }\n        } catch (e) {}\n\n        var now = new Date();\n        return now.toString().toLowerCase().includes(\'iran\');\n    };\n}\n\nif (typeof showPage === \'undefined\') {\n    var showPage = function showPage() {\n        if (!document.getElementsByClassName(\'redirect__captcha\')[0]) {\n            const placeholder = document.getElementById(\'arvanRecaptcha\');\n            const testDiv = document.createElement(\'div\');\n            testDiv.className = \'redirect__captcha\';\n            placeholder ...
#  {'page_number': 3,
#   'html_content': '<!DOCTYPE html><html lang="en"><head><meta charset="UTF-8"><meta name="viewport" content="width=device-width"><link href="/cdn-cgi/assets/css/static-pages-2.6.0.css" rel="stylesheet"><link rel="icon" type="image/x-icon" href="//#DOMAIN#/favicon.ico"><title></title></head><body><section class="error-section error-section--waiting error-section--ltr error-section--hide" id="en"><div class="container"><div class="error-section__wrapper error-section__wrapper--waiting"><div class="error-section__information"><h1 class="error-section__title"></h1><h1 class="error-section__subtitle error-section__subtitle--waiting">Checking your browser before accessing the website...</h1><div class="error-section__contents"><p class="error-section__content">Please complete the security check before accessing the website.</p></div><div class="redirect__captcha" id="captcha"></div></div></div></div></section><section class="error-section error-section--waiting error-section--hide" id="fa"><div class="container"><div class="error-section__wrapper error-section__wrapper--waiting"><div class="error-section__information"><h1 class="error-section__title"></h1><h1 class="error-section__subtitle error-section__subtitle--waiting">Ø¯Ø± Ø\xadØ§Ù\x84 Ø¨Ø±Ø±Ø³Û\x8c Ù\x85Ø±Ù\x88Ø±Ú¯Ø±Ø\x8c Ù¾Û\x8cØ´ Ø§Ø² Ø§Ù\x86ØªÙ\x82Ø§Ù\x84 Ø¨Ù\x87 Ø³Ø§Û\x8cØª Ù\x87Ø³ØªÛ\x8cÙ\x85 ...</h1><div class="error-section__contents"><p class="error-section__content">Ø¨Ø±Ø§Û\x8c Ø¯Ø³ØªØ±Ø³Û\x8c Ø¨Ù\x87 Ù\x88Ø¨â\x80\x8cØ³Ø§Û\x8cØª Ù\x85Ù\x88Ø±Ø¯Ù\x86Ø¸Ø±Ø\x8c Ú¯Ø²Û\x8cÙ\x86Ù\x87 Ø²Û\x8cØ± Ø±Ø§ ØªØ§Û\x8cÛ\x8cØ¯ Ú©Ù\x86Û\x8cØ¯.</p></div><div class="redirect__captcha" id="captcha_element"></div></div></div></div></section><script>"use strict";\n\nvar isTehranTimezone = function isTehranTimezone() {\n  try {\n    var intlName = window.Intl.DateTimeFormat().resolvedOptions().timeZone;\n    if (intlName) {\n      return intlName.toLowerCase().includes(\'tehran\');\n    }\n  } catch (e) {}\n\n  var now = new Date();\n  return now.toString().toLowerCase().includes(\'iran\');\n};\n\nvar showPage = function showPage() {\n  var errorPage;\n  var headTitleElement = document.getElementsByTagName(\'title\');\n\n  if (isTehranTimezone()) {\n    errorPage = document.getElementById(\'fa\');\n  } else {\n    errorPage = document.getElementById(\'en\');\n  }\n\n  var lang;\n  if (isTehranTimezone()) {\n    lang = \'fa\';\n  } else {\n    lang = \'en\';\n  }\n\n  var pageTitle = errorPage.getElementsByClassName(\'error-section__title\')[0].textContent;\n  headTitleElement[0].innerHTML = pageTitle;\n  errorPage.classList.remove(\'error-section--hide\');\n  afterShowPage(errorPage, lang)\n};\n\nwindow.addEventListener("load", showPage);</script><script type="text/javascript">window.AR_SiteKey = \'6Le8dMkUAAAAAEzy7WYOlWbYh0eun-xK0j5aXt6W\';\nwindow.AR_Key = \'__arcsrc\';\nwindow.AR_Domain = \'jobinja.ir\';\nwindow.AR_Age = \'900\';\nwindow.AR_SameSite = \'; SameSite=Lax\';</script>\n<script type="text/javascript" src="/cdn-cgi/assets/js/recaptcha.js"></script>\n<script id="arvanRecaptcha" defer="defer" async="async"></script>\n<script type="text/javascript">"use strict";\n\nif (typeof isTehranTimezone === \'undefined\') {\n    var isTehranTimezone = function isTehranTimezone() {\n        try {\n            var intlName = window.Intl.DateTimeFormat().resolvedOptions().timeZone;\n            if (intlName) {\n                return intlName.toLowerCase().includes(\'tehran\');\n            }\n        } catch (e) {}\n\n        var now = new Date();\n        return now.toString().toLowerCase().includes(\'iran\');\n    };\n}\n\nif (typeof showPage === \'undefined\') {\n    var showPage = function showPage() {\n        if (!document.getElementsByClassName(\'redirect__captcha\')[0]) {\n            const placeholder = document.getElementById(\'arvanRecaptcha\');\n            const testDiv = document.createElement(\'div\');\n            testDiv.className = \'redirect__captcha\';\n            placeholder ...

# %%
[
    {
        "url": "https://jobinja.ir/companies/dornica-4",
        "main_page": {
            "html_content": response.text,
        },
        "job_page": {
            "html_content": response.text,
        },
        "about_page": {
            "html_content": response.text,
        }
    },
]
# Out:
# [{'url': 'https://jobinja.ir/companies/dornica-4',
#   'main_page': {'html_content': '<!DOCTYPE html><html lang="en"><head><meta charset="UTF-8"><meta name="viewport" content="width=device-width"><link href="/cdn-cgi/assets/css/static-pages-2.6.0.css" rel="stylesheet"><link rel="icon" type="image/x-icon" href="//#DOMAIN#/favicon.ico"><title></title></head><body><section class="error-section error-section--waiting error-section--ltr error-section--hide" id="en"><div class="container"><div class="error-section__wrapper error-section__wrapper--waiting"><div class="error-section__information"><h1 class="error-section__title"></h1><h1 class="error-section__subtitle error-section__subtitle--waiting">Checking your browser before accessing the website...</h1><div class="error-section__contents"><p class="error-section__content">Please complete the security check before accessing the website.</p></div><div class="redirect__captcha" id="captcha"></div></div></div></div></section><section class="error-section error-section--waiting error-section--hide" id="fa"><div class="container"><div class="error-section__wrapper error-section__wrapper--waiting"><div class="error-section__information"><h1 class="error-section__title"></h1><h1 class="error-section__subtitle error-section__subtitle--waiting">Ø¯Ø± Ø\xadØ§Ù\x84 Ø¨Ø±Ø±Ø³Û\x8c Ù\x85Ø±Ù\x88Ø±Ú¯Ø±Ø\x8c Ù¾Û\x8cØ´ Ø§Ø² Ø§Ù\x86ØªÙ\x82Ø§Ù\x84 Ø¨Ù\x87 Ø³Ø§Û\x8cØª Ù\x87Ø³ØªÛ\x8cÙ\x85 ...</h1><div class="error-section__contents"><p class="error-section__content">Ø¨Ø±Ø§Û\x8c Ø¯Ø³ØªØ±Ø³Û\x8c Ø¨Ù\x87 Ù\x88Ø¨â\x80\x8cØ³Ø§Û\x8cØª Ù\x85Ù\x88Ø±Ø¯Ù\x86Ø¸Ø±Ø\x8c Ú¯Ø²Û\x8cÙ\x86Ù\x87 Ø²Û\x8cØ± Ø±Ø§ ØªØ§Û\x8cÛ\x8cØ¯ Ú©Ù\x86Û\x8cØ¯.</p></div><div class="redirect__captcha" id="captcha_element"></div></div></div></div></section><script>"use strict";\n\nvar isTehranTimezone = function isTehranTimezone() {\n  try {\n    var intlName = window.Intl.DateTimeFormat().resolvedOptions().timeZone;\n    if (intlName) {\n      return intlName.toLowerCase().includes(\'tehran\');\n    }\n  } catch (e) {}\n\n  var now = new Date();\n  return now.toString().toLowerCase().includes(\'iran\');\n};\n\nvar showPage = function showPage() {\n  var errorPage;\n  var headTitleElement = document.getElementsByTagName(\'title\');\n\n  if (isTehranTimezone()) {\n    errorPage = document.getElementById(\'fa\');\n  } else {\n    errorPage = document.getElementById(\'en\');\n  }\n\n  var lang;\n  if (isTehranTimezone()) {\n    lang = \'fa\';\n  } else {\n    lang = \'en\';\n  }\n\n  var pageTitle = errorPage.getElementsByClassName(\'error-section__title\')[0].textContent;\n  headTitleElement[0].innerHTML = pageTitle;\n  errorPage.classList.remove(\'error-section--hide\');\n  afterShowPage(errorPage, lang)\n};\n\nwindow.addEventListener("load", showPage);</script><script type="text/javascript">window.AR_SiteKey = \'6Le8dMkUAAAAAEzy7WYOlWbYh0eun-xK0j5aXt6W\';\nwindow.AR_Key = \'__arcsrc\';\nwindow.AR_Domain = \'jobinja.ir\';\nwindow.AR_Age = \'900\';\nwindow.AR_SameSite = \'; SameSite=Lax\';</script>\n<script type="text/javascript" src="/cdn-cgi/assets/js/recaptcha.js"></script>\n<script id="arvanRecaptcha" defer="defer" async="async"></script>\n<script type="text/javascript">"use strict";\n\nif (typeof isTehranTimezone === \'undefined\') {\n    var isTehranTimezone = function isTehranTimezone() {\n        try {\n            var intlName = window.Intl.DateTimeFormat().resolvedOptions().timeZone;\n            if (intlName) {\n                return intlName.toLowerCase().includes(\'tehran\');\n            }\n        } catch (e) {}\n\n        var now = new Date();\n        return now.toString().toLowerCase().includes(\'iran\');\n    };\n}\n\nif (typeof showPage === \'undefined\') {\n    var showPage = function showPage() {\n        if (!document.getElementsByClassName(\'redirect__captcha\')[0]) {\n            const placeholder = document.getElementById(\'arvanRecaptcha\');\n            const testDiv = document.createElement(\'div\');\n            testDiv.className = \'redirect__captcha\';\n          ...
#   'job_page': {'html_content': '<!DOCTYPE html><html lang="en"><head><meta charset="UTF-8"><meta name="viewport" content="width=device-width"><link href="/cdn-cgi/assets/css/static-pages-2.6.0.css" rel="stylesheet"><link rel="icon" type="image/x-icon" href="//#DOMAIN#/favicon.ico"><title></title></head><body><section class="error-section error-section--waiting error-section--ltr error-section--hide" id="en"><div class="container"><div class="error-section__wrapper error-section__wrapper--waiting"><div class="error-section__information"><h1 class="error-section__title"></h1><h1 class="error-section__subtitle error-section__subtitle--waiting">Checking your browser before accessing the website...</h1><div class="error-section__contents"><p class="error-section__content">Please complete the security check before accessing the website.</p></div><div class="redirect__captcha" id="captcha"></div></div></div></div></section><section class="error-section error-section--waiting error-section--hide" id="fa"><div class="container"><div class="error-section__wrapper error-section__wrapper--waiting"><div class="error-section__information"><h1 class="error-section__title"></h1><h1 class="error-section__subtitle error-section__subtitle--waiting">Ø¯Ø± Ø\xadØ§Ù\x84 Ø¨Ø±Ø±Ø³Û\x8c Ù\x85Ø±Ù\x88Ø±Ú¯Ø±Ø\x8c Ù¾Û\x8cØ´ Ø§Ø² Ø§Ù\x86ØªÙ\x82Ø§Ù\x84 Ø¨Ù\x87 Ø³Ø§Û\x8cØª Ù\x87Ø³ØªÛ\x8cÙ\x85 ...</h1><div class="error-section__contents"><p class="error-section__content">Ø¨Ø±Ø§Û\x8c Ø¯Ø³ØªØ±Ø³Û\x8c Ø¨Ù\x87 Ù\x88Ø¨â\x80\x8cØ³Ø§Û\x8cØª Ù\x85Ù\x88Ø±Ø¯Ù\x86Ø¸Ø±Ø\x8c Ú¯Ø²Û\x8cÙ\x86Ù\x87 Ø²Û\x8cØ± Ø±Ø§ ØªØ§Û\x8cÛ\x8cØ¯ Ú©Ù\x86Û\x8cØ¯.</p></div><div class="redirect__captcha" id="captcha_element"></div></div></div></div></section><script>"use strict";\n\nvar isTehranTimezone = function isTehranTimezone() {\n  try {\n    var intlName = window.Intl.DateTimeFormat().resolvedOptions().timeZone;\n    if (intlName) {\n      return intlName.toLowerCase().includes(\'tehran\');\n    }\n  } catch (e) {}\n\n  var now = new Date();\n  return now.toString().toLowerCase().includes(\'iran\');\n};\n\nvar showPage = function showPage() {\n  var errorPage;\n  var headTitleElement = document.getElementsByTagName(\'title\');\n\n  if (isTehranTimezone()) {\n    errorPage = document.getElementById(\'fa\');\n  } else {\n    errorPage = document.getElementById(\'en\');\n  }\n\n  var lang;\n  if (isTehranTimezone()) {\n    lang = \'fa\';\n  } else {\n    lang = \'en\';\n  }\n\n  var pageTitle = errorPage.getElementsByClassName(\'error-section__title\')[0].textContent;\n  headTitleElement[0].innerHTML = pageTitle;\n  errorPage.classList.remove(\'error-section--hide\');\n  afterShowPage(errorPage, lang)\n};\n\nwindow.addEventListener("load", showPage);</script><script type="text/javascript">window.AR_SiteKey = \'6Le8dMkUAAAAAEzy7WYOlWbYh0eun-xK0j5aXt6W\';\nwindow.AR_Key = \'__arcsrc\';\nwindow.AR_Domain = \'jobinja.ir\';\nwindow.AR_Age = \'900\';\nwindow.AR_SameSite = \'; SameSite=Lax\';</script>\n<script type="text/javascript" src="/cdn-cgi/assets/js/recaptcha.js"></script>\n<script id="arvanRecaptcha" defer="defer" async="async"></script>\n<script type="text/javascript">"use strict";\n\nif (typeof isTehranTimezone === \'undefined\') {\n    var isTehranTimezone = function isTehranTimezone() {\n        try {\n            var intlName = window.Intl.DateTimeFormat().resolvedOptions().timeZone;\n            if (intlName) {\n                return intlName.toLowerCase().includes(\'tehran\');\n            }\n        } catch (e) {}\n\n        var now = new Date();\n        return now.toString().toLowerCase().includes(\'iran\');\n    };\n}\n\nif (typeof showPage === \'undefined\') {\n    var showPage = function showPage() {\n        if (!document.getElementsByClassName(\'redirect__captcha\')[0]) {\n            const placeholder = document.getElementById(\'arvanRecaptcha\');\n            const testDiv = document.createElement(\'div\');\n            testDiv.className = \'redirect__captcha\';\n           ...
#   'about_page': {'html_content': '<!DOCTYPE html><html lang="en"><head><meta charset="UTF-8"><meta name="viewport" content="width=device-width"><link href="/cdn-cgi/assets/css/static-pages-2.6.0.css" rel="stylesheet"><link rel="icon" type="image/x-icon" href="//#DOMAIN#/favicon.ico"><title></title></head><body><section class="error-section error-section--waiting error-section--ltr error-section--hide" id="en"><div class="container"><div class="error-section__wrapper error-section__wrapper--waiting"><div class="error-section__information"><h1 class="error-section__title"></h1><h1 class="error-section__subtitle error-section__subtitle--waiting">Checking your browser before accessing the website...</h1><div class="error-section__contents"><p class="error-section__content">Please complete the security check before accessing the website.</p></div><div class="redirect__captcha" id="captcha"></div></div></div></div></section><section class="error-section error-section--waiting error-section--hide" id="fa"><div class="container"><div class="error-section__wrapper error-section__wrapper--waiting"><div class="error-section__information"><h1 class="error-section__title"></h1><h1 class="error-section__subtitle error-section__subtitle--waiting">Ø¯Ø± Ø\xadØ§Ù\x84 Ø¨Ø±Ø±Ø³Û\x8c Ù\x85Ø±Ù\x88Ø±Ú¯Ø±Ø\x8c Ù¾Û\x8cØ´ Ø§Ø² Ø§Ù\x86ØªÙ\x82Ø§Ù\x84 Ø¨Ù\x87 Ø³Ø§Û\x8cØª Ù\x87Ø³ØªÛ\x8cÙ\x85 ...</h1><div class="error-section__contents"><p class="error-section__content">Ø¨Ø±Ø§Û\x8c Ø¯Ø³ØªØ±Ø³Û\x8c Ø¨Ù\x87 Ù\x88Ø¨â\x80\x8cØ³Ø§Û\x8cØª Ù\x85Ù\x88Ø±Ø¯Ù\x86Ø¸Ø±Ø\x8c Ú¯Ø²Û\x8cÙ\x86Ù\x87 Ø²Û\x8cØ± Ø±Ø§ ØªØ§Û\x8cÛ\x8cØ¯ Ú©Ù\x86Û\x8cØ¯.</p></div><div class="redirect__captcha" id="captcha_element"></div></div></div></div></section><script>"use strict";\n\nvar isTehranTimezone = function isTehranTimezone() {\n  try {\n    var intlName = window.Intl.DateTimeFormat().resolvedOptions().timeZone;\n    if (intlName) {\n      return intlName.toLowerCase().includes(\'tehran\');\n    }\n  } catch (e) {}\n\n  var now = new Date();\n  return now.toString().toLowerCase().includes(\'iran\');\n};\n\nvar showPage = function showPage() {\n  var errorPage;\n  var headTitleElement = document.getElementsByTagName(\'title\');\n\n  if (isTehranTimezone()) {\n    errorPage = document.getElementById(\'fa\');\n  } else {\n    errorPage = document.getElementById(\'en\');\n  }\n\n  var lang;\n  if (isTehranTimezone()) {\n    lang = \'fa\';\n  } else {\n    lang = \'en\';\n  }\n\n  var pageTitle = errorPage.getElementsByClassName(\'error-section__title\')[0].textContent;\n  headTitleElement[0].innerHTML = pageTitle;\n  errorPage.classList.remove(\'error-section--hide\');\n  afterShowPage(errorPage, lang)\n};\n\nwindow.addEventListener("load", showPage);</script><script type="text/javascript">window.AR_SiteKey = \'6Le8dMkUAAAAAEzy7WYOlWbYh0eun-xK0j5aXt6W\';\nwindow.AR_Key = \'__arcsrc\';\nwindow.AR_Domain = \'jobinja.ir\';\nwindow.AR_Age = \'900\';\nwindow.AR_SameSite = \'; SameSite=Lax\';</script>\n<script type="text/javascript" src="/cdn-cgi/assets/js/recaptcha.js"></script>\n<script id="arvanRecaptcha" defer="defer" async="async"></script>\n<script type="text/javascript">"use strict";\n\nif (typeof isTehranTimezone === \'undefined\') {\n    var isTehranTimezone = function isTehranTimezone() {\n        try {\n            var intlName = window.Intl.DateTimeFormat().resolvedOptions().timeZone;\n            if (intlName) {\n                return intlName.toLowerCase().includes(\'tehran\');\n            }\n        } catch (e) {}\n\n        var now = new Date();\n        return now.toString().toLowerCase().includes(\'iran\');\n    };\n}\n\nif (typeof showPage === \'undefined\') {\n    var showPage = function showPage() {\n        if (!document.getElementsByClassName(\'redirect__captcha\')[0]) {\n            const placeholder = document.getElementById(\'arvanRecaptcha\');\n            const testDiv = document.createElement(\'div\');\n            testDiv.className = \'redirect__captcha\';\n         ...

# %%
[
    {
        "name": "Dornica",
        "website": "https://dornica.com",
        "size": "100-500",
        "category": "Software",
        "about": "Dornica is a software company that develops software for the automotive industry.",
    }
]
# Out:
# [{'name': 'Dornica',
#   'website': 'https://dornica.com',
#   'size': '100-500',
#   'category': 'Software',
#   'about': 'Dornica is a software company that develops software for the automotive industry.'}]
